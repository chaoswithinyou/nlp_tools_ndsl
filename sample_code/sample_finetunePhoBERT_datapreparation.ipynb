# %%
# !pip install py_vncorenlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting py_vncorenlp
#   Downloading py_vncorenlp-0.1.3.tar.gz (3.9 kB)
# Collecting pyjnius
#   Downloading pyjnius-1.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 5.1 MB/s
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius->py_vncorenlp) (1.15.0)
# Building wheels for collected packages: py-vncorenlp
#   Building wheel for py-vncorenlp (setup.py) ... done
#   Created wheel for py-vncorenlp: filename=py_vncorenlp-0.1.3-py3-none-any.whl size=4309 sha256=1fb72adbcb47a72d1b2c7298df136e0b24f1e740a29495d483572287af30120c
#   Stored in directory: /root/.cache/pip/wheels/87/be/55/d5930c1d90a09832e9afd57a9e13801e3d16c88f5a19f777ae
# Successfully built py-vncorenlp
# Installing collected packages: pyjnius, py-vncorenlp
# Successfully installed py-vncorenlp-0.1.3 pyjnius-1.4.2

# %%
import py_vncorenlp

# Automatically download VnCoreNLP components from the original repository
# and save them in some local machine folder
py_vncorenlp.download_model(save_dir='/content')

# Load the word and sentence segmentation component
rdrsegmenter = py_vncorenlp.VnCoreNLP(annotators=["wseg"], save_dir='/content')

text = "Ông Nguyễn Khắc Chúc  đang làm việc tại Đại học Quốc gia Hà Nội. Bà Lan, vợ ông Chúc, cũng làm việc tại đây."

output = rdrsegmenter.word_segment(text)

print(output)
# Out:
# ['Ông Nguyễn_Khắc_Chúc đang làm_việc tại Đại_học Quốc_gia Hà_Nội .', 'Bà Lan , vợ ông Chúc , cũng làm_việc tại đây .']

# %%
# !gdown 1ovLbpvzSGrS4NDxZu8Ftdgc73uHzNQJf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ovLbpvzSGrS4NDxZu8Ftdgc73uHzNQJf
# To: /content/corpus-full.7z
# 100% 3.92G/3.92G [00:23<00:00, 168MB/s]

# %%
# !pip install py7zr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting py7zr
#   Downloading py7zr-0.20.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.1 MB/s
# Collecting brotli>=1.0.9
#   Downloading Brotli-1.0.9-cp37-cp37m-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 10.6 MB/s
# Collecting pyppmd<0.19.0,>=0.18.1
#   Downloading pyppmd-0.18.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      |████████████████████████████████| 138 kB 39.1 MB/s
# Collecting texttable
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Collecting pyzstd>=0.14.4
#   Downloading pyzstd-0.15.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (379 kB)
#      |████████████████████████████████| 379 kB 42.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from py7zr) (5.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from py7zr) (5.4.8)
# Collecting pycryptodomex>=3.6.6
#   Downloading pycryptodomex-3.15.0-cp35-abi3-manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 47.0 MB/s
# Collecting pybcj>=0.6.0
#   Downloading pybcj-1.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.5 MB/s
# Collecting multivolumefile>=0.2.3
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64>=0.3.0
#   Downloading inflate64-0.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92 kB)
#      |████████████████████████████████| 92 kB 9.4 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->py7zr) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->py7zr) (4.1.1)
# Installing collected packages: texttable, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, brotli, py7zr
# Successfully installed brotli-1.0.9 inflate64-0.3.0 multivolumefile-0.2.3 py7zr-0.20.0 pybcj-1.0.1 pycryptodomex-3.15.0 pyppmd-0.18.3 pyzstd-0.15.3 texttable-1.6.4

# %%
import py7zr
with py7zr.SevenZipFile("/content/corpus-full.7z", mode='r') as z:
    z.extractall('/content/text')

# %% [markdown]
# File Size is 18968.530076026917 MB
# <br>Number of Lines in the file is 111274300
# <br>Peak Memory Usage = 196244
# <br>User Mode Time = 339.681173
# <br>System Mode Time = 20.270266

# %%
import resource
import os
from tqdm.notebook import tqdm

file_name = "/content/text/corpus-full.txt"

#print(f'File Size is {os.stat(file_name).st_size / (1024 * 1024)} MB')

txt_file = open(file_name)

count = 0

for line in tqdm(txt_file):
    # we can process file line by line here, for simplicity I am taking count of lines
    count += 1
    if count < 10000000:
        with open('/content/word_seg_corpus_valid.txt', "a") as fh:
            word_seg_line = rdrsegmenter.word_segment(line)[0]
            fh.write(word_seg_line+'\n')
    elif count < 20000000:
        with open('/content/word_seg_corpus_test.txt', "a") as fh:
            word_seg_line = rdrsegmenter.word_segment(line)[0]
            fh.write(word_seg_line+'\n')
    else:
        with open('/content/word_seg_corpus_train.txt', "a") as fh:
            word_seg_line = rdrsegmenter.word_segment(line)[0]
            fh.write(word_seg_line+'\n')

txt_file.close()

#print(f'Number of Lines in the file is {count}')

print('Peak Memory Usage =', resource.getrusage(resource.RUSAGE_SELF).ru_maxrss)
print('User Mode Time =', resource.getrusage(resource.RUSAGE_SELF).ru_utime)
print('System Mode Time =', resource.getrusage(resource.RUSAGE_SELF).ru_stime)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-52c4d2f90c75> in <module>
#      16     if count < 10000000:
#      17         with open('/content/word_seg_corpus_valid.txt', "a") as fh:
# ---> 18             word_seg_line = rdrsegmenter.word_segment(line)[0]
#      19             fh.write(word_seg_line+'\n')
#      20     elif count < 20000000:
#
# /usr/local/lib/python3.7/dist-packages/py_vncorenlp/vncorenlp.py in word_segment(self, text)
#      91         from jnius import autoclass
#      92         javaclass_Annotation = autoclass('vn.pipeline.Annotation')
# ---> 93         str = self.javaclass_String(text)
#      94         annotation = javaclass_Annotation(str)
#      95         self.model.annotate(annotation)
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp /content/word_seg_corpus_valid.txt /content/drive/MyDrive/z_inf_data

# %%
word_seg_line[0]
# Out:
# 'Chây_ì nộp phạt nguội .'
