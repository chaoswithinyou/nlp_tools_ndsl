# %%
import os
cwd = os.getcwd()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
#!cp /content/corpus-cate-csv-2019-24-03.7z /content/drive/MyDrive/NLP
# Out:
# Mounted at /content/drive

# %%
try:
    f = open(cwd+"/bert_data_cnndm_final.zip")
    # Do something with the file
    f.close()
except IOError:
    # !gdown 1DN7ClZCCXsk2KegmC6t4ClBwtAf5galI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DN7ClZCCXsk2KegmC6t4ClBwtAf5galI
# To: /content/bert_data_cnndm_final.zip
# 100% 1.14G/1.14G [00:21<00:00, 53.8MB/s]

# %%
# !git clone https://github.com/chriskhanhtran/PreSumm
# Out:
# Cloning into 'PreSumm'...
# remote: Enumerating objects: 467, done.
# remote: Total 467 (delta 0), reused 0 (delta 0), pack-reused 467
# Receiving objects: 100% (467/467), 13.09 MiB | 10.02 MiB/s, done.
# Resolving deltas: 100% (300/300), done.

# %%
import zipfile
with zipfile.ZipFile(cwd+"/bert_data_cnndm_final.zip", 'r') as zip_ref:
    zip_ref.extractall('/content/PreSumm/bert_data')

# %%
# !pip install -r /content/PreSumm/requirements.txt

# %%
# !python /content/PreSumm/src/train.py -other_bert distilbert -task ext -mode train -bert_data_path /content/PreSumm/bert_data/bert_data_cnndm_final/cnndm -ext_dropout 0.1 -model_path MODEL_PATH -lr 2e-3 -visible_gpus 0 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -log_file /content/PreSumm/logs/ext_bert_cnndm -ext_dropout 0.1 -model_path MODEL_PATH -lr 2e-3 -visible_gpus -1 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -log_file /content/PreSumm/logs/ext_bert_cnndm -use_interval true -warmup_steps 10000 -max_pos 512

# %%
# !python /content/PreSumm/src/train.py -other_bert distilbert -task ext -mode train -bert_data_path /content/PreSumm/bert_data/bert_data_cnndm_final/cnndm -ext_dropout 0.1 -model_path MODEL_PATH -lr 2e-3 -visible_gpus 0 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -log_file /content/PreSumm/logs/ext_bert_cnndm -use_interval true -warmup_steps 10000 -max_pos 512

# %%
# !gdown 1ovLbpvzSGrS4NDxZu8Ftdgc73uHzNQJf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ovLbpvzSGrS4NDxZu8Ftdgc73uHzNQJf
# To: /content/corpus-full.7z
# 100% 3.92G/3.92G [00:45<00:00, 86.7MB/s]

# %%
try:
    f = open(cwd+"/corpus-cate-csv-2019-24-03.7z")
    # Do something with the file
    f.close()
except IOError:
    # !gdown 1-Av37aKdF6j82j1hK-p2XllTtbSNqaSc
#full text 1z7QNMT_H_ABKHzm2ydT_wDEI4XY6jGHW

# %%
# !pip install py7zr

# %%
import py7zr
with py7zr.SevenZipFile("/content/drive/MyDrive/NLP/corpus-cate-csv-2019-24-03.7z", mode='r') as z:
    z.extractall('/content/text')

# %%
i = 0
with open('/content/text/corpus-full.txt','r') as f:
    for line in f:
        print(line)
        i += 1
        if i==100:
          break

# %%
N = 50
with open('/content/text/corpus-full.txt','r') as myfile:
    head = [next(myfile) for x in range(N)]
print(head)
# Out:
# ['Chây ì nộp phạt nguội.\n', "Hàng chục ngàn phương tiện bị ghi hình vi phạm luật giao thông ở TP.HCM, bị 'bêu tên' nhưng chủ vẫn không chịu nộp phạt.\n", 'Trên cổng thông tin điện tử của Công an TP.HCM (CATP), mục thông tin về phương tiện vi phạm hành chính qua hình ảnh (từ ngày 4.1.2017 - 4.1.2018), có ghi nhận biển số xe, lỗi vi phạm, ngày vi phạm của 34.118 phương tiện (ô tô) chưa nộp phạt.\n', 'Đây là các phương tiện vi phạm được camera (di động hoặc cố định) của CATP ghi hình phạt nguội .\n', 'Điều đáng nói, dù Phòng CSGT đường bộ - đường sắt (PC67), CATP nhiều lần gửi giấy thông báo vi phạm về công an địa phương nhưng chủ hoặc người điều khiển phương tiện vẫn chưa thực hiện quyết định xử phạt hành chính.\n', 'Phổ biến nhất là lỗi đỗ không đúng nơi quy định.\n', 'Chẳng hạn từ tháng 1 - 7.2017, ô tô BS: 14A-130... 23 lần đỗ không đúng nơi quy định trên đường Hàm Nghi, Q.1; từ tháng 3 - 10.2017, ô tô BS: 30S-087... 34 lần đỗ trên đường Nguyễn Cư Trinh, Q.1; từ tháng 4 - 10.2017, 
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/text/Công nghệ.csv')

df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                     title  \
# 0       Công nghệ Blockchain: Tác động lớn đến các nền...
# 1       Avvanz đẩy mạnh công nghệ Blockchain thông qua...
# 2       Blockchain là nền tảng của cuộc cách mạng công...
# 3       Quỹ đầu tư Hồng Kông sẽ mua lại sàn giao dịch ...
# 4       Lần đầu tiên có câu lạc bộ chữ ký số và giao d...
# ...                                                   ...
# 615858     Samsung Louvre B7610: “Dế” dành cho doanh nhân
# 615859                          Click chuột để… luyện thi
# 615860            Microsoft cho không phần mềm bảo mật PC
# 615861            Microsoft cho không phần mềm bảo mật PC
# 615862         Vista thoát kiếp 'ế' sau một năm phát hành
#
# ...
