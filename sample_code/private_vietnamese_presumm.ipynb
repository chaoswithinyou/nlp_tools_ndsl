# %% [markdown]
# #Initial procedure

# %%
import os
cwd = os.getcwd()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
#!cp /content/corpus-cate-csv-2019-24-03.7z /content/drive/MyDrive/NLP
# Out:
# Mounted at /content/drive

# %%
from IPython.display import clear_output

# %% [markdown]
# #Setup presumm

# %%
# !git clone --branch newtorch --single-branch https://github.com/chaoswithinyou/PreSumm.git
# Out:
# Cloning into 'PreSumm'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 272 (delta 34), reused 39 (delta 18), pack-reused 214
# Receiving objects: 100% (272/272), 13.08 MiB | 16.78 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
# !git clone --branch newtorch https://github.com/chaoswithinyou/PreSumm.git fetch all but check out at this brance

# %%
# !pip install -r /content/PreSumm/requirements.txt
clear_output()

# %%
# !rm -rf /content/PreSumm

# %%
# !cp /content/drive/MyDrive/NLP/cnndm_sample.train.0.bert.pt /content/PreSumm/bert_data

# %%
# !python /content/PreSumm/src/train.py -other_bert phobert -task ext -mode train -bert_data_path /content/PreSumm/bert_data/cnndm_sample -model_path MODEL_PATH -lr 2e-3 -report_every 1 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -ext_dropout 0.1 -visible_gpus -1 -log_file /content/PreSumm/logs/ext_bert_cnndm -use_interval true -warmup_steps 10000 -max_pos 256

# %%
# !python /content/PreSumm/src/train.py -other_bert phobert -task ext -mode train -bert_data_path /content/PreSumm/bert_data/cnndm_sample -model_path MODEL_PATH -lr 2e-3 -report_every 50 -save_checkpoint_steps 1000 -batch_size 3000 -train_steps 50000 -accum_count 2 -ext_dropout 0.1 -visible_gpus 0 -log_file /content/PreSumm/logs/ext_bert_cnndm -use_interval true -warmup_steps 10000 -max_pos 512

# %% [markdown]
# #Download presumm dataset

# %%
try:
    f = open(cwd+"/bert_data_cnndm_final.zip")
    # Do something with the file
    f.close()
except IOError:
    # !gdown 1DN7ClZCCXsk2KegmC6t4ClBwtAf5galI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DN7ClZCCXsk2KegmC6t4ClBwtAf5galI
# To: /content/bert_data_cnndm_final.zip
# 100% 1.14G/1.14G [00:05<00:00, 202MB/s]

# %%
import zipfile
with zipfile.ZipFile(cwd+"/bert_data_cnndm_final.zip", 'r') as zip_ref:
    zip_ref.extractall('/content/PreSumm/bert_data')

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/NLP/cong_nghe.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/PreSumm/bert_data')

# %% [markdown]
# #Fix bug

# %%
import pickle

# %%
# !pwd
# Out:
# /content/PreSumm/src

# %%
# %cd /content/PreSumm/src
# Out:
# /content/PreSumm/src

# %%
# !python www.py
# Out:
# Traceback (most recent call last):
#   File "www.py", line 13, in <module>
#     sent_scores, mask = model(src1, src1, src1, mm, mm)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/PreSumm/src/models/model_builder.py", line 207, in forward
#     top_vec = self.bert(src, segs, mask_src)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/PreSumm/src/models/model_builder.py", line 163, in forward
#     top_vec, _ = self.model(input_ids=x, token_type_ids=segs, attention_mask=mask)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_bert.py", line 727, in forward
#     input_ids=input_ids, position_ids=position_ids, token_type_ids=token_type_ids, inputs_embeds=inputs_embeds
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_roberta.py", line 65, in forward
#     input_ids, token_type_ids=token_type_ids, position_ids=position_ids, inputs_embeds=inputs_embeds
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_bert.py", line 174, in forward
#     position_embeddings = self.position_embeddings(position_ids)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/sparse.py", line 117, in forward
#     self.norm_type, self.scale_grad_by_freq, self.sparse)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py", line 1506, in embedding
#     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
# RuntimeError: index out of range at /pytorch/aten/src/TH/generic/THTensorEvenMoreMath.cpp:193

# %%
# 256 khong loi 257 loi

# %%
try:
    sent_scores, mask = self.model(src, segs, clss, mask, mask_cls)
except:
    pickle.dump(self.model,open('/content/model.p','wb'))
    pickle.dump(src,open('/content/src.p','wb'))
    pickle.dump(segs,open('/content/segs.p','wb'))
    pickle.dump(clss,open('/content/clss.p','wb'))
    pickle.dump(mask,open('/content/mask.p','wb'))
    pickle.dump(mask_cls,open('/content/mask_cls.p','wb'))

# %%
import pickle
import torch

src = pickle.load(open('/content/src.p','rb'))
src1 = torch.zeros(11,256).long()
mm = torch.zeros((11,256),dtype=torch.uint8)
model = pickle.load(open('/content/model.p','rb'))
segs = pickle.load(open('/content/segs.p','rb'))
clss = pickle.load(open('/content/clss.p','rb'))
mask = pickle.load(open('/content/mask.p','rb'))
mask_cls = pickle.load(open('/content/mask_cls.p','rb'))

sent_scores, mask = model(src, src1, clss, mask, mask_cls)
#sent_scores, mask = model(src, segs, clss, mask, mask_cls)

#print(model)
# print(src)
# print(segs)
# print(clss)
# print(mask)
# print(mask_cls)

#print(model.bert.model.config.vocab_size)

# %%
src = pickle.load(open('/content/src.p','rb'))
segs = pickle.load(open('/content/segs.p','rb'))
clss = pickle.load(open('/content/clss.p','rb'))
mask = pickle.load(open('/content/mask.p','rb'))
mask_cls = pickle.load(open('/content/mask_cls.p','rb'))

# %%
sent_scores, mask = model(src, segs, clss, mask, mask_cls)

# %%
import pickle

# %%
torch.max(src)
# Out:
# tensor(59318)

# %%
torch.zeros(11,258).size()
# Out:
# torch.Size([11, 258])

# %%
src.size()
# Out:
# torch.Size([5, 512])

# %% [markdown]
# #Prepare dataset

# %%
try:
    f = open(cwd+"/corpus-cate-csv-2019-24-03.7z")
    # Do something with the file
    f.close()
except IOError:
    # !gdown 1-Av37aKdF6j82j1hK-p2XllTtbSNqaSc
#full text 1z7QNMT_H_ABKHzm2ydT_wDEI4XY6jGHW

# %%
# !pip install py7zr

# %%
import py7zr
with py7zr.SevenZipFile("/content/drive/MyDrive/NLP/corpus-cate-csv-2019-24-03.7z", mode='r') as z:
    z.extractall('/content/text')

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/NLP/Công_nghệ.csv')
#df = pd.read_csv('/content/drive/MyDrive/NLP/Công nghệ.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(df.index)
# Out:
# 615863

# %%
# !pip3 install py_vncorenlp
clear_output()

# %%
import py_vncorenlp
# import os
# cwd = os.getcwd()
py_vncorenlp.download_model(save_dir='/content')
rdrsegmenter = py_vncorenlp.VnCoreNLP(annotators=["wseg"], save_dir='/content')

# %%
segmented_text = rdrsegmenter.word_segment(df.iloc[2500]['content'])

# %%
from nltk import tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !cp /content/PreSumm/bert_data/cnndm_sample.train.0.bert.pt /content/drive/MyDrive/NLP

# %%
from tqdm import tqdm

# %%
# !mkdir json

# %%
import json
part = []
part_index = 0
count = 0
#for i in tqdm(range(len(df.index))):
for i in tqdm(range(len(df.index))):
    segmented_content = rdrsegmenter.word_segment(df.iloc[i]['content'])[:-2]
    if len(segmented_content)>5:
        sapo = df.iloc[i]['sapo']
        if sapo == df.iloc[i]['sapo']:
            segmented_goldsum = [rdrsegmenter.word_segment(df.iloc[i]['title'])[0]+'.']+rdrsegmenter.word_segment(sapo)
            part.append({"src":[tokenize.word_tokenize(x) for x in segmented_content], "tgt":[tokenize.word_tokenize(x) for x in segmented_goldsum]})
            count += 1
    if count == 1999:
        with open(f"/content/json/cnndm_sample.train.{part_index}.json", "w+") as outfile:
            json.dump(part, outfile)
        part = []
        part_index += 1
        count = 0
with open(f"/content/json/cnndm_sample.train.{part_index}.json", "w+") as outfile:
    json.dump(part, outfile)
# Out:
# 100%|██████████| 615863/615863 [3:42:57<00:00, 46.04it/s]

# %%
len(part)
# Out:
# 8330

# %%
with open("/content/json/cnndm_sample.train.0.json", "w+") as outfile:
    json.dump(part, outfile)

# %%
# !cp /content/PreSumm/src/others/added_vocab.txt /content

# %%
# !python /content/PreSumm/src/preprocess.py -mode format_to_bert -raw_path /content/json -save_path /content/PreSumm/bert_data  -lower -n_cpus 1 -log_file /content/PreSumm/logs/preprocess.log
# Out:
# [('train', '/content/json/cnndm_sample.train.196.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/json', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.196.bert.pt'), ('train', '/content/json/cnndm_sample.train.145.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/json', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.145.bert.pt'), ('train', '/content/json/cnndm_sample.train.177.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/json', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.177.bert.pt'), ('train', '/content/json/cnndm_sample.train.114.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/json', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.114.bert.pt'), ('train', '/content/json/cnndm_sample.train.63.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/json', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.63.bert.pt'), ('train', '/content/json/cnndm_sample.train.82.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/json', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.82.bert.pt'), ('train', '/content/json/cnndm_sample.train.199.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/json', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.199.bert.pt'), ('train', '/content/json/cnndm_sample.train.179.json', Namespace(dataset='', log_file='/content/PreSumm/logs/pr ...
# [2022-10-09 16:24:16,025 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 16:24:16,214 INFO] Processing /content/json/cnndm_sample.train.196.json
# [2022-10-09 16:24:23,289 INFO] Processed instances 1999
# [2022-10-09 16:24:23,290 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.196.bert.pt
# [2022-10-09 16:24:24,924 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 16:24:25,068 INFO] Processing /content/json/cnndm_sample.train.145.json
# [2022-10-09 16:24:31,667 INFO] Processed instances 1999
# [2022-10-09 16:24:31,667 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.145.bert.pt
# [2022-10-09 16:24:33,248 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 16:24:33,383 INFO] Processing /content/json/cnndm_sample.train.177.json
# [2022-10-09 16:24:40,327 INFO] Processed instances 1999
# [2022-10-09 16:24:40,328 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.177.bert.pt
# [2022-10-09 16:24:41,956 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 16:24:42,096 INFO] Processing /content/json/cnndm_sample.train.114.json
# [2022-10-09 16:24:48,378 INFO] Processed instances 1999
# [2022-10-09 16:24:48,379 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.114.bert.pt
# [2022-10-09 16:24:49,927 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 16:24:50,062 INFO] Processing /content/json/cnndm_sample.train.63.json
# [2022-10-09 16:24:56,576 INFO] Processed instances 1999
# [2022-10-09 16:24:56,576 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train
INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 17:00:14,827 INFO] Processing /content/json/cnndm_sample.train.102.json
# [2022-10-09 17:00:20,951 INFO] Processed instances 1999
# [2022-10-09 17:00:20,951 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.102.bert.pt
# [2022-10-09 17:00:22,457 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 17:00:22,593 INFO] Processing /content/json/cnndm_sample.train.166.json
# [2022-10-09 17:00:29,249 INFO] Processed instances 1999
# [2022-10-09 17:00:29,249 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.166.bert.pt
# [2022-10-09 17:00:30,829 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 17:00:30,968 INFO] Processing /content/json/cnndm_sample.train.73.json
# [2022-10-09 17:00:37,542 INFO] Processed instances 1999
# [2022-10-09 17:00:37,542 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.73.bert.pt
# [2022-10-09 17:00:39,128 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 17:00:39,268 INFO] Processing /content/json/cnndm_sample.train.249.json
# [2022-10-09 17:00:45,832 INFO] Processed instances 1988
# [2022-10-09 17:00:45,832 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.249.bert.pt
# [2022-10-09 17:00:47,385 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 17:00:47,524 INFO] Processing /content/json/cnndm_sample.train.180.json
# [2022-10-09 17:00:54,823 INFO] Processed instances 1999
# [2022-10-09 17:00:54,823 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.180.bert.pt
# [2022-10-09 17:00:56,497 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-09 17:00:56,638 INFO] Processing /content/json/cnndm_sample.train.33.json
# [2022-10-09 17:01:03,495 INFO] Processed instances 1999
# [2022-10-09 17:01:03,495 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.33.bert.pt
# []
# []

# %%
# !python /content/PreSumm/src/preprocess.py -mode format_to_bert -raw_path /content/PreSumm/json_data -save_path /content/PreSumm/bert_data  -lower -n_cpus 1 -log_file /content/PreSumm/logs/preprocess.log
# Out:
# [('train', '/content/PreSumm/json_data/cnndm_sample.train.0.json', Namespace(dataset='', log_file='/content/PreSumm/logs/preprocess.log', lower=True, map_path='../../data/', max_src_nsents=100, max_src_ntokens_per_sent=200, max_tgt_ntokens=500, min_src_nsents=3, min_src_ntokens_per_sent=5, min_tgt_ntokens=5, mode='format_to_bert', n_cpus=1, pretrained_model='bert', raw_path='/content/PreSumm/json_data', save_path='/content/PreSumm/bert_data', select_mode='greedy', shard_size=2000, use_bert_basic_tokenizer=False), '/content/PreSumm/bert_data/cnndm_sample.train.0.bert.pt')]
# [2022-10-07 07:16:11,661 INFO] loading vocabulary file https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt from cache at /root/.cache/torch/pytorch_transformers/0a34bc276f86df145cf05b9794f10e391ecb455423d9352e9db04f1422b4d42d.26ba0c8945e559c68d0bc35d24fea16f5463a49fe8f134e0c32261d590b577fa
# [2022-10-07 07:16:11,867 INFO] Processing /content/PreSumm/json_data/cnndm_sample.train.0.json
# [2022-10-07 07:16:11,918 INFO] Processed instances 6
# [2022-10-07 07:16:11,918 INFO] Saving to /content/PreSumm/bert_data/cnndm_sample.train.0.bert.pt
# []
# []

# %%
import shutil
shutil.make_archive('cong_nghe', 'zip', '/content/PreSumm/bert_data')
# Out:
# '/content/aaa.zip'

# %%
# !cp /content/cong_nghe.zip /content/drive/MyDrive/NLP

# %% [markdown]
# #Check lendoc

# %%
lendoc = []
for i in part:
    a = [item for sublist in i['src'] for item in sublist]
    lendoc.append(len(a))

# %%
count = 0
for i in lendoc:
    if i>1000:
        count += 1
count

# %%
lendoc

# %% [markdown]
# #Fix vocab problems

# %%
# !pip install -U transformers

# %%
# !pip show transformers

# %%
import torch

# %%
dataset = torch.load("/content/PreSumm/bert_data/cnndm_sample.train.0.bert.pt")
len(dataset)
# Out:
# 8789

# %%
dataset = torch.load("/content/drive/MyDrive/NLP/cnndm_sample.train.0.bert.pt")
len(dataset)
# Out:
# 8328

# %%
dataset = torch.load('/content/PreSumm/bert_data/bert_data_cnndm_final/cnndm.train.122.bert.pt')
len(dataset)
# Out:
# 2000

# %%
dataset[0]

# %%
# !pip install -U transformers

# %%
import torch
from transformers import AutoModel, AutoTokenizer, PhobertTokenizer

phobert = AutoModel.from_pretrained("vinai/phobert-base")
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")

# INPUT TEXT MUST BE ALREADY WORD-SEGMENTED!
sentence = 'Chúng_tôi là những nghiên_cứu_viên .'  

input_ids = torch.tensor([tokenizer.encode(sentence)])

with torch.no_grad():
    features = phobert(input_ids)  # Models outputs are now tuples

## With TensorFlow 2.0+:
# from transformers import TFAutoModel
# phobert = TFAutoModel.from_pretrained("vinai/phobert-base")

# %%
import collections
def load_vocab(vocab_file):
    """Loads a vocabulary file into a dictionary."""
    vocab = collections.OrderedDict()
    index = 0
    with open('/content/PreSumm/src/others/added_vocab.txt', "r", encoding="utf-8") as reader:
        while True:
            token = reader.readline()
            if not token:
                break
            token = token.strip()
            token = token.split()
            vocab[token[0]] = index
            index += 1
    with open(vocab_file, "r", encoding="utf-8") as reader:
        while True:
            token = reader.readline()
            if not token:
                break
            token = token.strip()
            token = token.split()
            vocab[token[0]] = index
            index += 1
    last_1 = list(vocab.keys())[-1]
    last_2 = list(vocab.keys())[-2]
    last_3 = list(vocab.keys())[-3]
    vocab['[unused0]'] = vocab[last_3]
    vocab['[unused1]'] = vocab[last_2]
    vocab['[unused2]'] = vocab[last_1]
    del vocab[last_1]
    del vocab[last_2]
    del vocab[last_3]
    vocab['[mask]'] = index
    return vocab

# %%
# !wget https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt
# Out:
# --2022-10-07 06:38:08--  https://huggingface.co/vinai/phobert-base/raw/main/vocab.txt
# Resolving huggingface.co (huggingface.co)... 52.5.54.249, 54.210.225.113, 44.195.102.200, ...
# Connecting to huggingface.co (huggingface.co)|52.5.54.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 895321 (874K) [text/plain]
# Saving to: ‘vocab.txt’
#
# vocab.txt           100%[===================>] 874.34K  --.-KB/s    in 0.1s
#
# 2022-10-07 06:38:09 (6.34 MB/s) - ‘vocab.txt’ saved [895321/895321]

# %%
# !wget https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt

# %%
vocab = load_vocab('/content/vocab.txt')

# %%
len(vocab.items())
# Out:
# 64001

# %%
idx2word = {v: k for k, v in vocab.items()}

# %%
idx2word[64000]
# Out:
# '[mask]'

# %%
vocab['[unused1]'] = vocab.pop(list(vocab.keys())[-2])

# %%
vocab['[unused1]']
# Out:
# 63997

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
sep_token = '[SEP]'
cls_token = '[CLS]'
pad_token = '[PAD]'
tgt_bos = '[unused0]'
tgt_eos = '[unused1]'
tgt_sent_split = '[unused2]'
sep_vid = tokenizer.vocab[sep_token]
cls_vid = tokenizer.vocab[cls_token]
pad_vid = tokenizer.vocab[pad_token]
