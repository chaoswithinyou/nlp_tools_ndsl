# %%
# current directory
# !pwd
# Out:
# /content

# %%
# private file
# !wget -O a.py https://raw.githubusercontent.com/chaoswithinyou/tiktok_text2speech/main/clear_temp.py?token=GHSAT0AAAAAABZNAAAA3A4UUZ2U5L7NESKOYZXCQ5A

# %%
# public file
# !wget https://github.com/chaoswithinyou/RedditVideoMakerBot/blob/master/reddit/subreddit.py

# %%
# !wget -e robots=off https://github.com/chaoswithinyou/RedditVideoMakerBot/blob/master/reddit/
# Out:
# --2022-09-30 16:17:53--  https://github.com/chaoswithinyou/RedditVideoMakerBot/blob/master/reddit/
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/chaoswithinyou/RedditVideoMakerBot/tree/master/reddit [following]
# --2022-09-30 16:17:53--  https://github.com/chaoswithinyou/RedditVideoMakerBot/tree/master/reddit
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [ <=>                ] 119.24K  --.-KB/s    in 0.04s
#
# 2022-09-30 16:17:54 (3.14 MB/s) - ‘index.html’ saved [122101]

# %%
from IPython.display import clear_output 
# !pip3 install --user gitdir
clear_output()
# !/root/.local/bin/gitdir https://github.com/chaoswithinyou/nlp_tools_ndsl/tree/main/word_segmentation
clear_output()

# %%
# !pip install datasets
from datasets import list_datasets, load_dataset
dataset = load_dataset('uit-nlp/vietnamese_students_feedback')
clear_output()

# %%
from word_segmentation.UITws import word_segment
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
segmented_texts = word_segment(dataset['train']['sentence'])

# %%
t = "Ông Nguyễn Khắc Chúc đang làm việc tại Đại học Quốc gia Hà Nội. Bà Lan, vợ ông Chúc, cũng làm việc tại đây."
t2 = [t,t]
t3 = "Ông Nguyễn Khắc Chúc đang làm việc tại Đại học Quốc gia Hà Nội."

# %%
word_segment(t)

# %%
word_segment(t, single_text=True)
# Out:
# ['Ông Nguyễn_Khắc_Chúc đang làm_việc tại Đại_học Quốc_gia Hà_Nội.',
#  'Bà Lan, vợ ông Chúc, cũng làm_việc tại đây.']

# %%
tokenize.sent_tokenize(t3)
# Out:
# ['Ông Nguyễn Khắc Chúc đang làm việc tại Đại học Quốc gia Hà Nội.']

# %%
from nltk import tokenize
import nltk
#nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokenize.sent_tokenize(t)
# Out:
# ['Ông Nguyễn Khắc Chúc đang làm việc tại Đại học Quốc gia Hà Nội.',
#  'Bà Lan, vợ ông Chúc, cũng làm việc tại đây.']

# %%
tokenize.word_tokenize(word_segment([t])[0])
# Out:
# ['Ông',
#  'Nguyễn_Khắc_Chúc',
#  'đang',
#  'làm_việc',
#  'tại',
#  'Đại_học',
#  'Quốc_gia',
#  'Hà_Nội._Bà_Lan',
#  ',',
#  'vợ',
#  'ông',
#  'Chúc',
#  ',',
#  'cũng',
#  'làm_việc',
#  'tại',
#  'đây',
#  '.']

# %%
word_segment(t2)
# Out:
# ['Ông Nguyễn_Khắc_Chúc  đang làm_việc tại Đại_học Quốc_gia Hà_Nội._Bà_Lan, vợ ông Chúc, cũng làm_việc tại đây.',
#  'Ông Nguyễn_Khắc_Chúc  đang làm_việc tại Đại_học Quốc_gia Hà_Nội._Bà_Lan, vợ ông Chúc, cũng làm_việc tại đây.']

# %%
# !pip3 install py_vncorenlp
clear_output()
import py_vncorenlp
py_vncorenlp.download_model(save_dir='/content')
rdrsegmenter = py_vncorenlp.VnCoreNLP(annotators=["wseg"], save_dir='/content')

# %%
import os
cwd = os.getcwd()

# %%
import time

# %%
start_time = time.time()
segmented_texts = [rdrsegmenter.word_segment(comment)[0] for comment in dataset['train']['sentence']]
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 4.61295485496521 seconds ---

# %%
segmented_texts[8]
# Out:
# 'nội_dung môn_học có phần thiếu trọng_tâm , hầu_như là chung_chung , khái_quát khiến sinh_viên rất khó nắm được nội_dung môn_học .'

# %%
start_time = time.time()
segmented_texts = word_segment(dataset['train']['sentence'])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 20.625368356704712 seconds ---

# %%
segmented_texts[8]
# Out:
# 'nội_dung môn_học có phần thiếu trọng_tâm , hầu_như là chung_chung , khái_quát khiến sinh_viên rất khó nắm được nội_dung môn_học .'

# %%
# from utils.videos import save_data
# from utils import settings

# %%
# from drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !cp /content/drive/MyDrive/NLP/UITws_v1.py /content
# from UITws_v1 import UITws_v1
# Out:
# Mounted at /content/drive

# %%
import pickle
vectors = pickle.load(open('/content/drive/MyDrive/NLP/word_vectors.p','rb'))
pickle.dump(vectors, open('/content/drive/MyDrive/NLP/word_vectors.p', 'wb'))

# %%
# !wget https://public.vinai.io/word2vec_vi_words_100dims.zip
# Out:
# --2022-10-01 19:50:38--  https://public.vinai.io/word2vec_vi_words_100dims.zip
# Resolving public.vinai.io (public.vinai.io)... 18.160.200.105, 18.160.200.9, 18.160.200.53, ...
# Connecting to public.vinai.io (public.vinai.io)|18.160.200.105|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 785783878 (749M) [application/zip]
# Saving to: ‘word2vec_vi_words_100dims.zip’
#
# word2vec_vi_words_1 100%[===================>] 749.38M  16.0MB/s    in 47s
#
# 2022-10-01 19:51:27 (15.8 MB/s) - ‘word2vec_vi_words_100dims.zip’ saved [785783878/785783878]

# %%
import os
cwd = os.getcwd()

# %%
import zipfile
with zipfile.ZipFile(cwd+'/word2vec_vi_words_100dims.zip', 'r') as zip_ref:
    zip_ref.extractall(cwd)

# %%
import numpy as np
from tqdm import tqdm

# %%
words = []
idx = -1
word2idx = {}
vectors = []

with open('/content/word2vec_vi_words_100dims.txt', 'rb') as f:
    for l in tqdm(f):
        line = l.decode().split(' ')
        word = line[0]
        words.append(word)
        word2idx[word] = idx
        idx += 1
        vect = np.array(line[1:]).astype(np.float)
        vectors.append(vect)
del vectors[0]
del word2idx['1587507']
del words[0]
vectors = np.array(vectors)
# Out:
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# 1587508it [02:31, 10475.06it/s]

# %%
vietnamese_w2v = {w: vectors[word2idx[w]] for w in words}

# %%
import pickle

# %%
pickle.dump(word2idx, open(cwd+'/vietnamese_word2idx.p', 'wb'))

# %%
w2v = [words, word2idx, vectors]

# %%
del words
del word2idx
del vectors

# %%
pickle.dump(w2v, open(cwd+'/vietnamese_w2v.pickle', 'wb'))

# %%
pickle.dump(w2v, open('/content/drive/MyDrive/NLP/vietnamese_PhoW2V_100dims.pickle', 'wb'))

# %%
del w2v

# %%
# 300dims w2v
# !gdown --id 1rA7rGOEuhzfTzEiSiH-MiqWhQeR_ETTi
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1rA7rGOEuhzfTzEiSiH-MiqWhQeR_ETTi
# To: /content/vietnamese_PhoW2V.pickle
# 100% 3.86G/3.86G [00:27<00:00, 140MB/s]

# %%
PhoW2V_300dims = pickle.load(open(cwd+'/vietnamese_PhoW2V_300dims.pickle','rb'))

# %%
vietnamese_w2v = {w: PhoW2V[2][PhoW2V[1][w]] for w in PhoW2V[0]}

# %%
vietnamese_w2v['nắng']
# Out:
# array([ 0.00424855,  0.26149476, -0.18614876, -0.06582042,  0.08535242,
#         0.0127572 ,  0.04308655, -0.0889672 , -0.12646022, -0.00072392,
#         0.01414262,  0.0019784 , -0.12523417,  0.00281593,  0.03855883,
#         0.00674484, -0.14630386,  0.1322712 ,  0.05582492,  0.05461809,
#         0.17622593, -0.04894169, -0.09552112, -0.11553556,  0.02921049,
#        -0.10583312, -0.1138694 ,  0.25692856, -0.02512098,  0.00817622,
#         0.02637313, -0.2518325 , -0.17825398,  0.03353566,  0.08568138,
#         0.1095034 , -0.07049458,  0.0705227 ,  0.17182782,  0.02585446,
#         0.02065753, -0.03024568,  0.08063223, -0.13935691, -0.02736235,
#         0.00644172,  0.03337246,  0.05307832, -0.06773606,  0.11441784,
#         0.03451912, -0.0236202 , -0.03931376, -0.1060155 ,  0.03355112,
#         0.00461228,  0.04281265, -0.1678852 ,  0.14185141,  0.08906958,
#        -0.03032453, -0.12337224,  0.03627777,  0.03711026, -0.08095506,
#        -0.16300583,  0.00368966, -0.03832132,  0.02129467, -0.06480622,
#        -0.2846402 ,  0.02482219,  0.00369997, -0.04853358,  0.02962411,
#        -0.10478284, -0.04565285,  0.06376855, -0.03782773,  0.11064988,
#        -0.02970522, -0.08096235, -0.04004825, -0.11958328, -0.08517563,
#        -0.01731906,  0.25262484, -0.01123012, -0.07731321, -0.01105389,
#        -0.16224247, -0.05994663,  0.0332915 ,  0.04869496, -0.15296859,
#        -0.05696921,  0.03096124, -0.148268  , -0.09636192,  0.04932331])

# %%
del PhoW2V

# %%
# 100dims w2v
# !gdown --id 1--bdQosASIlc3O4xN5IZ5vLfZ_yEdfBZ
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1--bdQosASIlc3O4xN5IZ5vLfZ_yEdfBZ
# To: /content/vietnamese_PhoW2V_100dims.pickle
# 100% 1.32G/1.32G [00:06<00:00, 196MB/s]

# %%
PhoW2V_100dims = pickle.load(open(cwd+'/vietnamese_PhoW2V_100dims.pickle','rb'))
