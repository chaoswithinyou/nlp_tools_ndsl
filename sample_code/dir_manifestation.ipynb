# %%
# current directory
# !pwd

# %%
# private file
# !wget -O a.py https://raw.githubusercontent.com/chaoswithinyou/tiktok_text2speech/main/clear_temp.py?token=GHSAT0AAAAAABZNAAAA3A4UUZ2U5L7NESKOYZXCQ5A

# %%
# public file
# !wget https://github.com/chaoswithinyou/RedditVideoMakerBot/blob/master/reddit/subreddit.py

# %%
# !wget -e robots=off https://github.com/chaoswithinyou/RedditVideoMakerBot/blob/master/reddit/
# Out:
# --2022-09-30 16:17:53--  https://github.com/chaoswithinyou/RedditVideoMakerBot/blob/master/reddit/
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/chaoswithinyou/RedditVideoMakerBot/tree/master/reddit [following]
# --2022-09-30 16:17:53--  https://github.com/chaoswithinyou/RedditVideoMakerBot/tree/master/reddit
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [ <=>                ] 119.24K  --.-KB/s    in 0.04s
#
# 2022-09-30 16:17:54 (3.14 MB/s) - ‘index.html’ saved [122101]

# %%
# !pip3 install --user gitdir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitdir
#   Downloading gitdir-1.2.7.tar.gz (4.9 kB)
# Collecting colorama~=0.4
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: gitdir
#   Building wheel for gitdir (setup.py) ... done
#   Created wheel for gitdir: filename=gitdir-1.2.7-py3-none-any.whl size=5658 sha256=93ec804a2532ba203bab1d5f28f41e34f99ffc2abdf2a75e9c6a667bb746c31d
#   Stored in directory: /root/.cache/pip/wheels/87/59/b8/1af9734953accb0daf9eada11a87d991dfa3050cac877cec0d
# Successfully built gitdir
# Installing collected packages: colorama, gitdir
#   WARNING: The script gitdir is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed colorama-0.4.5 gitdir-1.2.7

# %%
# !/root/.local/bin/gitdir https://github.com/chaoswithinyou/RedditVideoMakerBot/tree/master/utils
# Out:
# Downloaded: .config.template.toml
# Downloaded: CONSTANTS.py
# Downloaded: __init__.py
# Downloaded: cleanup.py
# Downloaded: console.py
# Downloaded: id.py
# Downloaded: settings.py
# Downloaded: subreddit.py
# Downloaded: version.py
# Downloaded: video.py
# Downloaded: videos.py
# Downloaded: voice.py
# ✔ Download complete

# %%
# from utils.videos import save_data
# from utils import settings

# %%
# from drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !cp /content/drive/MyDrive/NLP/UITws_v1.py /content
from UITws_v1 import UITws_v1

# %%
import pickle
vectors = pickle.load(open('/content/drive/MyDrive/NLP/word_vectors.p','rb'))
pickle.dump(vectors, open('/content/drive/MyDrive/NLP/word_vectors.p', 'wb'))
